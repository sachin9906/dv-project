# %%
import pandas as pd

# Load the data
census_tract_data = pd.read_csv('/kaggle/input/us-census-demographic-data/acs2015_census_tract_data.csv')
county_data = pd.read_csv('/kaggle/input/us-census-demographic-data/acs2015_county_data.csv')

# Data preprocessing steps (e.g., handling missing values, data cleaning) if needed
# ...

# Explore the structure and features of the dataset
census_tract_data.head()
county_data.head()
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
# 1      1003  Alabama  Baldwin    195121  95314  99807       4.5   83.1    9.5
# 2      1005  Alabama  Barbour     26932  14497  12435       4.6   46.2   46.7
# 3      1007  Alabama     Bibb     22604  12073  10531       2.2   74.5   21.4
# 4      1009  Alabama   Blount     57710  28512  29198       8.6   87.9    1.5
#
#    Native  ...  Walk  OtherTransp  WorkAtHome  MeanCommute  Employed  \
# 0     0.4  ...   0.5          1.3         1.8         26.5     23986
# 1     0.6  ...   1.0          1.4         3.9         26.4     85953
# 2     0.2  ...   1.8          1.5         1.6         24.1      8597
# 3     0.4  ...   0.6          1.5         0.7         28.8      8294
# 4     0.3  ...   0.9          0.4         2.3         34.9     22189
#
#    PrivateWork  PublicWork  SelfEmployed  FamilyWork  Unemployment
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Perform EDA to understand the data and relationships

# Plot histograms for selected columns
columns_to_plot = ['TotalPop', 'Men', 'Women', 'Hispanic', 'White', 'Black']
data_to_plot = data[columns_to_plot]

plt.figure(figsize=(12, 8))
for i, column in enumerate(data_to_plot.columns):
    plt.subplot(2, 3, i+1)
    sns.histplot(data_to_plot[column], kde=True)
    plt.title(f'Histogram of {column}')

plt.subplots_adjust(wspace=0.5, hspace=0.5)  # Adjust spacing between subplots
plt.show()

# Plot a pairplot for relationships between numerical columns
sns.pairplot(data_to_plot)
plt.suptitle('Pairplot of Selected Columns', y=1.02)
plt.show()

# Plot a correlation matrix heatmap
correlation_matrix = data_to_plot.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', cbar=True, square=True)
plt.title('Correlation Matrix Heatmap')
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
